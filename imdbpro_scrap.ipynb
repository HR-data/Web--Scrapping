# %%
from bs4 import BeautifulSoup 
import requests 
import re
import json
from selenium import webdriver
import pandas as pd
from urllib.request import urlopen as uReq

# %%
url = 'https://pro.imdb.com/inproduction?ref_=hm_nv_tt_tmm#type=movie%2CtvSeries%2CtvEpisode%2CtvMovie%2CtvMiniSeries&country=US%2CGB%2CCA%2CAU%2CFR&filmingLocation=india&sort=ranking&pos=0'
resp = uReq(url) # where url is the above url 
page_html=resp.read()
resp.close()
bs = BeautifulSoup(page_html,'html.parser')
t=bs.findAll("div",{"class":"full_page logged_in default_search"})
#print(soup)

bs
# Out:
# <!DOCTYPE doctype html>
# <!--[if IE 8]><html class="a-no-js a-lt-ie10 a-lt-ie9 a-ie8" data-19ax5a9jf="dingo"><![endif]--><!--[if IE 9]><html class="a-no-js a-lt-ie10 a-ie9" data-19ax5a9jf="dingo"><![endif]--><!--[if !IE]><!--><html class="a-no-js" data-19ax5a9jf="dingo"><!--<![endif]--><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/> <meta content="https://m.media-amazon.com/images/G/01/IMDbPro/images/share/social_sharing_imdb_logo-3939248796._CB466644808_.png" property="og:image">
# <title dir="ltr">IMDbPro Official Site | Start Your Free Trial</title> <link href="https://m.media-amazon.com/images/G/01/IMDbPro/images/favicon-689397331._CB468424755_.ico" rel="shortcut icon"/>
# <link href="https://m.media-amazon.com/images/G/01/IMDbPro/images/mobile/pro_icon_48x48-3843847253._CB468227465_.png" rel="apple-touch-icon"/>
# ...

# %%
cont=t[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-e7ae95fef2b5> in <module>
# ----> 1 cont=t[0]
#
# IndexError: list index out of range

# %%
print(len(movie))
# Out:
# 0
